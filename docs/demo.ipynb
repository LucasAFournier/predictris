# %% [markdown]
# # Online Sensorimotor Sequence-based Learning with Predictive Trees — Demo

# %% [markdown]
# In this demo, we use a tiny, Tetris-inspired model using simple actions to demonstrate:
# * How Predictive Trees grow during learning.
# * How to measure accuracy by defining a testing method.

# %% [markdown]
# ## Predictris Package

# %%
# %cd C:/Users/lucas/Desktop/GitHub/predictris
# !pip install -e .
# Out:
# C:\Users\lucas\Desktop\GitHub\predictris
# c:\Users\lucas\Desktop\GitHub\predictris\.venv\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# Obtaining file:///C:/Users/lucas/Desktop/GitHub/predictris
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests>=2.28.0 in c:\users\lucas\desktop\github\predictris\.venv\lib\site-packages (from predictris==0.1.0) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lucas\desktop\github\predictris\.venv\lib\site-packages (from requests>=2.28.0->predictris==0.1.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lucas\desktop\github\predictris\.venv\lib\site-packages (from requests>=2.28.0->predictris==0.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lucas\desktop\github\predictris\.venv\lib\site-packages (from requests>=2.28.0->predictris==0.1.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lucas\desktop\github\predictris\.venv\lib\site-packages (from requests>=2.28.0->predictris==0.1.0) (2024.12.14)
# Building wheels for collected packages: predictris
#   Building editable for predictris (pyproject.toml): started
#   Building editable for predictris (pyproject.toml): finished with status 'done'
#   Created wheel for predictris: filename=predictris-0.1.0-py3-none-any.whl size=19488 sha256=3aeaca9f7da1ac897e8e3e198ffb2a59ebce9fd41825de9c31abf516ef50f28d
#   Stored in directory: C:\Users\lucas\AppData\Local\Temp\pip-ephem-wheel-cache-9w_ilrpu\wheels\c5\41\9f\475c4b130e3b42f09042d1361f5804fa276347fd850d796972
# Successfully built predictris
# Installing collected packages: predictris
#   Attempting uninstall: predictris
#     Found existing installation: predictris 0.1.0
#     Uninstalling predictris-0.1.0:
#       Successfully uninstalled predictris-0.1.0
# Successfully installed predictris-0.1.0
# [notice] A new release of pip is available: 25.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Evolution of Prediction Trees

# %% [markdown]
# ### Setup

# %%
from IPython.display import Image

# %% [markdown]
# ### Depth 1

# %%
# !python scripts/get_metrics.py --tetrominos J S --depth 1 --total-steps 6000 --verbose --save --nodes-count --confidences
# Out:
# [1/1] tetrominos=JS_depth=1_action=random_activation=all: 100% 6000/6000 [00:02<00:00, 2300.10it/s]

# %%
# !python scripts/plot_metrics.py --dirs "tetrominos=JS_depth=1" --output "tetrominos=JS_depth=1.png" --metrics "nodes_count" "confidences"
Image('plots/metrics/tetrominos=JS_depth=1.png')
# Out:
# Figure(400x500)
# C:\Users\lucas\Desktop\GitHub\predictris\src\predictris\plot.py:102: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend(loc="best")

# %% [markdown]
# ### Depth 2

# %%
# !python scripts/get_metrics.py --tetrominos J S --depth 2 --total-steps 500000 --verbose --save --nodes-count --confidences
# Out:
# [1/1] tetrominos=JS_depth=2_action=random_activation=all: 100% 500000/500000 [06:07<00:00, 1361.60it/s]

# %%
# !python scripts/plot_metrics.py --dirs "tetrominos=JS_depth=2" --output "tetrominos=JS_depth=2.png" --metrics "nodes_count" "confidences"
Image('plots/metrics/tetrominos=JS_depth=2.png')
# Out:
# Figure(400x500)
# C:\Users\lucas\Desktop\GitHub\predictris\src\predictris\plot.py:102: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend(loc="best")

# %% [markdown]
# ### Depth 3

# %%
# !python scripts/get_metrics.py --tetrominos J S --depth 3 --total-steps 1000000 --verbose --save --nodes-count --confidences
# Out:
# [1/1] tetrominos=JS_depth=3_action=random_activation=all:  50% 502090/1000000 [25:07<24:55, 333.05it/s]

# %%
# !python scripts/plot_metrics.py --dirs "tetrominos=JS_depth=3" --output "tetrominos=JS_depth=3.png" --metrics "nodes_count" "confidences"
Image('plots/metrics/tetrominos=JS_depth=3.png')
# Out:
# Figure(400x500)
# C:\Users\lucas\Desktop\GitHub\predictris\src\predictris\plot.py:102: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend(loc="best")

# %% [markdown]
# ## Measuring Accuracy

# %%
# !python scripts/get_error_rates.py --tetrominos J S --depth 1 --total-steps 50000 --reps 10 --verbose --save
# !python scripts/get_error_rates.py --tetrominos J S --depth 2 --total-steps 50000 --reps 10 --verbose --save
# !python scripts/get_error_rates.py --tetrominos J S --depth 3 --total-steps 50000 --reps 10 --verbose --save
# Out:
# [1/10] tetrominos=JS_depth=1: 100% 50000/50000 [00:23<00:00, 2158.43it/s]
# [2/10] tetrominos=JS_depth=1: 100% 50000/50000 [00:23<00:00, 2114.12it/s]
# [3/10] tetrominos=JS_depth=1: 100% 50000/50000 [00:23<00:00, 2126.19it/s]
# [4/10] tetrominos=JS_depth=1: 100% 50000/50000 [00:22<00:00, 2269.97it/s]
# [5/10] tetrominos=JS_depth=1: 100% 50000/50000 [00:23<00:00, 2104.91it/s]
# [6/10] tetrominos=JS_depth=1: 100% 50000/50000 [00:23<00:00, 2107.37it/s]
# [7/10] tetrominos=JS_depth=1: 100% 50000/50000 [00:22<00:00, 2271.43it/s]
# [8/10] tetrominos=JS_depth=1: 100% 50000/50000 [00:23<00:00, 2130.01it/s]
# [9/10] tetrominos=JS_depth=1: 100% 50000/50000 [00:23<00:00, 2093.46it/s]
# [10/10] tetrominos=JS_depth=1: 100% 50000/50000 [00:25<00:00, 1985.68it/s]
# [1/10] tetrominos=JS_depth=2: 100% 50000/50000 [00:50<00:00, 982.55it/s]
# [2/10] tetrominos=JS_depth=2: 100% 50000/50000 [00:52<00:00, 955.43it/s]
# [3/10] tetrominos=JS_depth=2: 100% 50000/50000 [00:52<00:00, 954.91it/s]
# [4/10] tetrominos=JS_depth=2: 100% 50000/50000 [00:52<00:00, 948.78it/s]
# [5/10] tetrominos=JS_depth=2: 100% 50000/50000 [00:54<00:00, 914.36it/s]
# [6/10] tetrominos=JS_depth=2: 100% 50000/50000 [00:51<00:00, 964.64it/s]
# [7/10] tetrominos=JS_depth=2: 100% 50000/50000 [00:51<00:00, 965.77it/s]
# [8/10] tetrominos=JS_depth=2: 100% 50000/50000 [00:53<00:00, 936.66it/s]
# [9/10] tetrominos=JS_depth=2: 100% 50000/50000 [00:52<00:00, 960.36it/s]
# [10/10] tetrominos=JS_depth=2: 100% 50000/50000 [00:53<00:00, 930.26it/s]
# [1/10] tetrominos=JS_depth=3: 100% 50000/50000 [01:36<00:00, 519.49it/s]
# [2/10] tetrominos=JS_depth=3: 100% 50000/50000 [01:37<00:00, 515.10it/s]
# [3/10] tetrominos=JS_depth=3: 100% 50000/50000 [01:42<00:00, 488.36it/s]
# [4/10] tetrominos=JS_depth=3: 100% 50000/50000 [01:41<00:00, 494.75it/s]
# [5/10] tetrominos=JS_depth=3: 100% 50000/50000 [01:44<00:00, 478.24it/s]
# [6/10] tetrominos=JS_depth=3: 100% 50000/50000 [01:45<00:00, 474.01it/s]
# [7/10] tetrominos=JS_depth=3: 100% 50000/50000 [01:47<00:00, 465.60it/s]
# [8/10] tetrominos=JS_depth=3: 100% 50000/50000 [01:50<00:00, 453.61it/s]
# [9/10] tetrominos=JS_depth=3: 100% 50000/50000 [01:46<00:00, 468.77it/s]
# [10/10] tetrominos=JS_depth=3: 100% 50000/50000 [01:47<00:00, 466.78it/s]

# %%
# !python scripts/plot_error_rates.py --dirs "tetrominos=JS_depth=1" "tetrominos=JS_depth=2" "tetrominos=JS_depth=3" --step 3 --output "tetrominos=JS.png"
Image('plots/error-rates/tetrominos=JS.png')
# Out:
# Figure(1000x500)

# %%
# !python scripts/get_error_rates.py --tetrominos I J L O S T Z --depth 1 --total-steps 100000 --reps 10 --verbose --save
# !python scripts/get_error_rates.py --tetrominos I J L O S T Z --depth 2 --total-steps 100000 --reps 10 --verbose --save
# !python scripts/get_error_rates.py --tetrominos I J L O S T Z --depth 3 --total-steps 100000 --reps 10 --verbose --save
# Out:
# [1/10] tetrominos=IJLOSTZ_depth=1: 100% 100000/100000 [01:18<00:00, 1266.38it/s]
# [2/10] tetrominos=IJLOSTZ_depth=1: 100% 100000/100000 [01:18<00:00, 1271.02it/s]
# [3/10] tetrominos=IJLOSTZ_depth=1: 100% 100000/100000 [01:20<00:00, 1249.22it/s]
# [4/10] tetrominos=IJLOSTZ_depth=1: 100% 100000/100000 [01:19<00:00, 1255.50it/s]
# [5/10] tetrominos=IJLOSTZ_depth=1: 100% 100000/100000 [01:18<00:00, 1269.36it/s]
# [6/10] tetrominos=IJLOSTZ_depth=1: 100% 100000/100000 [01:19<00:00, 1257.67it/s]
# [7/10] tetrominos=IJLOSTZ_depth=1: 100% 100000/100000 [01:19<00:00, 1262.11it/s]
# [8/10] tetrominos=IJLOSTZ_depth=1: 100% 100000/100000 [01:20<00:00, 1241.16it/s]
# [9/10] tetrominos=IJLOSTZ_depth=1: 100% 100000/100000 [01:24<00:00, 1185.24it/s]
# [10/10] tetrominos=IJLOSTZ_depth=1: 100% 100000/100000 [01:20<00:00, 1245.40it/s]
# [1/10] tetrominos=IJLOSTZ_depth=2: 100% 100000/100000 [03:03<00:00, 544.87it/s]
# [2/10] tetrominos=IJLOSTZ_depth=2: 100% 100000/100000 [03:03<00:00, 546.00it/s]
# [3/10] tetrominos=IJLOSTZ_depth=2: 100% 100000/100000 [03:02<00:00, 547.91it/s]
# [4/10] tetrominos=IJLOSTZ_depth=2: 100% 100000/100000 [03:04<00:00, 542.55it/s]
# [5/10] tetrominos=IJLOSTZ_depth=2: 100% 100000/100000 [03:06<00:00, 536.91it/s]
# [6/10] tetrominos=IJLOSTZ_depth=2: 100% 100000/100000 [03:06<00:00, 536.76it/s]
# [7/10] tetrominos=IJLOSTZ_depth=2: 100% 100000/100000 [03:05<00:00, 538.31it/s]
# [8/10] tetrominos=IJLOSTZ_depth=2: 100% 100000/100000 [03:04<00:00, 542.23it/s]
# [9/10] tetrominos=IJLOSTZ_depth=2: 100% 100000/100000 [03:08<00:00, 531.76it/s]
# [10/10] tetrominos=IJLOSTZ_depth=2: 100% 100000/100000 [03:08<00:00, 530.32it/s]
# [1/10] tetrominos=IJLOSTZ_depth=3: 100% 100000/100000 [06:57<00:00, 239.81it/s]
# [2/10] tetrominos=IJLOSTZ_depth=3: 100% 100000/100000 [07:03<00:00, 236.00it/s]
# [3/10] tetrominos=IJLOSTZ_depth=3: 100% 100000/100000 [07:04<00:00, 235.43it/s]
# [4/10] tetrominos=IJLOSTZ_depth=3: 100% 100000/100000 [07:06<00:00, 234.22it/s]
# [5/10] tetrominos=IJLOSTZ_depth=3: 100% 100000/100000 [07:00<00:00, 237.67it/s]
# [6/10] tetrominos=IJLOSTZ_depth=3: 100% 100000/100000 [07:00<00:00, 237.97it/s]
# [7/10] tetrominos=IJLOSTZ_depth=3: 100% 100000/100000 [07:06<00:00, 234.31it/s]
# [8/10] tetrominos=IJLOSTZ_depth=3: 100% 100000/100000 [07:05<00:00, 235.27it/s]
# [9/10] tetrominos=IJLOSTZ_depth=3: 100% 100000/100000 [07:00<00:00, 238.04it/s]
# [10/10] tetrominos=IJLOSTZ_depth=3: 100% 100000/100000 [06:59<00:00, 238.12it/s]

# %%
# !python scripts/plot_error_rates.py --dirs "tetrominos=IJLOSTZ_depth=1" "tetrominos=IJLOSTZ_depth=2" "tetrominos=IJLOSTZ_depth=3" --step 3 --output "tetrominos=IJLOSTZ.png"
Image('plots/error-rates/tetrominos=IJLOSTZ.png')
# Out:
# Figure(1500x600)

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ### Setup

# %%
from IPython.display import HTML, display
from google.colab import output
# !pip install pyvis

# %%
get_ipython().system_raw('python3 -m http.server --directory . 8000 > /dev/null 2>&1 &')

# %% [markdown]
# ### Depth 1

# %%
# !python scripts/learn.py --tetrominos J S --depth 1 --total-steps 5000 --verbose --save
# Out:
# Training on tetrominos=JS_depth=1: 100% 5000/5000 [00:01<00:00, 3792.41it/s]
#
# Saving trees to tetrominos=JS_depth=1

# %%
# !python scripts/render_trees.py --dir "tetrominos=JS_depth=1"

# %%
output.serve_kernel_port_as_iframe(
    8000,
    path='visualizations/tetrominos=JS_depth=1/selector.html',
    height=600,
    width='100%',
    cache_in_notebook=False,
)

# %% [markdown]
# ### Depth 2

# %%
# !python scripts/learn.py --tetrominos J S --depth 2 --total-steps 40000 --verbose --save
# Out:
# Training on tetrominos=JS_depth=2: 100% 40000/40000 [00:26<00:00, 1506.13it/s]
#
# Saving trees to tetrominos=JS_depth=2

# %%
# !python scripts/render_trees.py --dir "tetrominos=JS_depth=2"

# %%
output.serve_kernel_port_as_iframe(
    8000,
    path='visualizations/tetrominos=JS_depth=2/selector.html',
    height=600,
    width='100%',
    cache_in_notebook=False,
)

# %% [markdown]
# ### Depth 3

# %%
# !python scripts/learn.py --tetrominos J S --depth 3 --total-steps 50000 --verbose --save
# Out:
# Training on tetrominos=JS_depth=3: 100% 50000/50000 [01:13<00:00, 678.39it/s]
#
# Saving trees to tetrominos=JS_depth=3

# %%
# !python scripts/render_trees.py --dir "tetrominos=JS_depth=3"

# %%
output.serve_kernel_port_as_iframe(
    8000,
    path='visualizations/tetrominos=JS_depth=3/selector.html',
    height=600,
    width='100%',
    cache_in_notebook=False,
)
